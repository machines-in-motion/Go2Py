# %% [markdown]
# # Test in Simulation

# %%
from Go2Py.sim.mujoco import Go2Sim
from Go2Py.robot.fsm import FSM
from Go2Py.robot.remote import KeyboardRemote
from Go2Py.robot.safety import SafetyHypervisor

# %%
robot = Go2Sim()
remote = KeyboardRemote()
safety_hypervisor = SafetyHypervisor(robot)

# %%
robot.sitDownReset()
fsm = FSM(robot, remote, safety_hypervisor)

# %%
fsm.close()
robot.close()

# %% [markdown]
# # Test on Real Robot

# %%
from Go2Py.robot.interface import GO2Real
import time
from Go2Py.robot.fsm import FSM
from Go2Py.robot.remote import KeyboardRemote
from Go2Py.robot.safety import SafetyHypervisor
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.8.19)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
robot = GO2Real(mode='lowlevel')
time.sleep(1)
robot.getJointStates()
# Out:
# {'q': [-0.04003429412841797,
#   1.2656452655792236,
#   -2.785709857940674,
#   0.061743274331092834,
#   1.2621634006500244,
#   -2.805234670639038,
#   -0.3449947237968445,
#   1.2651857137680054,
#   -2.807509422302246,
#   0.3376070261001587,
#   1.274753451347351,
#   -2.795835494995117],
#  'dq': [0.011626571416854858,
#   -0.05813286080956459,
#   0.03235219791531563,
#   0.0,
#   0.0,
#   -0.028308173641562462,
#   -0.007751047611236572,
#   -0.054257333278656006,
#   0.02022012509405613,
#   0.01937761902809143,
#   0.03875523805618286,
#   0.0],
#  'tau_est': [-0.22264453768730164,
#   0.07421484589576721,
#   -0.3319052755832672,
#   -0.14842969179153442,
#   -0.12369140982627869,
#   0.1422451138496399,
#   0.024738281965255737,
#   0.049476563930511475,
#   -0.09483008086681366,
#   0.024738281965255737,
#   -0.024738281965255737,
#   0.09483008086681366],
#  'temperature': [31.0,
#   30.0,
#   30.0,
#   30.0,
#   29.0,
#   30.0,
#   32.0,
#   30.0,
#   30.0,
#   32.0,
#   29.0,
#   30.0]}

# %%
remote = KeyboardRemote()
safety_hypervisor = SafetyHypervisor(robot)
# Out:
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/opt/conda/envs/go2py/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/envs/go2py/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/conda/envs/go2py/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/Go2py/Go2Py/robot/remote.py", line 187, in _listen_to_keyboard
#     with keyboard.Listener(on_press=self._on_press, on_release=self._on_release) as listener:
# NameError: name 'keyboard' is not defined

# %%
fsm = FSM(robot, remote, safety_hypervisor)

# %%
fsm.close()
