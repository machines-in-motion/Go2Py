# %% [markdown]
# # Simulaion

# %%
import numpy as np
import time
from scipy.spatial.transform import Rotation as R
from Go2Py.sim.mujoco import Go2Sim
from Go2Py.robot.model import Go2Model
import mujoco

# Initiate the robot model 
model = Go2Model()
robot = Go2Sim(mode='lowlevel')
robot.standUpReset()

# %%
robot.model.opt.gravity[2] = 0

# %%
while True:
    q = robot.getJointStates()["q"]
    print(q)
    time.sleep(1)

# %%
# Data to be stored
data = [] # should contain q, q_target, dq, tau_est, tau

# %%
import numpy as np

def generate_traj(A, f, t, current_foot_poses):
    """
    Generate the foot trajectories using a sine wave and modify the current foot positions.

    Args:
        A (float): Amplitude of the sine wave in centimeters.
        f (float): Frequency of the sine wave in Hz.
        t (float): Current time in seconds.
        current_foot_poses (dict): A dictionary where keys are frame names (e.g., 'FR_foot') 
                                   and values are 4x4 transformation matrices.

    Returns:
        np.ndarray: A numpy array of size 12 containing the modified foot positions 
                    in the world frame (flattened as [FR_x, FR_y, FR_z, FL_x, FL_y, FL_z, ...]).
    """
    A = A / 100  # Convert amplitude to meters
    omega = 2 * np.pi * f
    x_traj = A * np.cos(omega * t)  # X trajectory (circular motion)
    z_traj = A * np.sin(omega * t)  # Z trajectory (circular motion)
    y_traj = A * np.sin(2 * omega * t)  # Y trajectory (lateral motion)

    x_traj_off = A * np.cos(omega * t + np.pi)  # X trajectory (circular motion)
    z_traj_off = A * np.sin(omega * t + np.pi)  # Z trajectory (circular motion)
    y_traj_off = A * np.sin(2 * omega * t + np.pi) 

    # Offsets for each foot
    feet_offsets = {
        # 'FR_foot': np.array([x_traj_off, y_traj_off, z_traj_off]),
        'FL_foot': np.array([x_traj, y_traj, z_traj]),
        # 'RR_foot': np.array([x_traj, y_traj, z_traj]),  
        # 'RL_foot': np.array([x_traj_off, y_traj_off, z_traj_off]),
    }

    # Store the updated foot positions in a numpy array
    feet_pos = np.zeros(12)  # 4 feet × 3 coordinates (x, y, z)

    foot_order = ['FR_foot', 'FL_foot', 'RR_foot', 'RL_foot']  # Ensure correct order
    for i, foot in enumerate(foot_order):
        if foot in current_foot_poses:
            # Extract translation (position) from the homogeneous transformation matrix
            translation = current_foot_poses[foot][:3, 3]  
            # Apply the offset
            modified_translation = translation + feet_offsets[foot]
            # Store in the numpy array
            feet_pos[3 * i: 3 * i + 3] = modified_translation  

    return feet_pos  # Returns a 12-element numpy array

# %%
def getT():
    position, quaternion = robot.getPose()
    rotation_matrix = R.from_quat([quaternion[1], quaternion[2], quaternion[3], quaternion[0]]).as_matrix()
    T = np.eye(4)
    T[:3, :3] = rotation_matrix
    T[:3, 3] = position
    
    return T

# %%
# Data Collector 
T = np.eye(4)
state = robot.getJointStates()
# model.updateAllPose(state['q'], state['dq'], T, np.zeros(6))

start_time = time.time()
q_nominal = state['q']
# nominal_foot_poses = model.forwardKinematics(T, q_nominal) # Get nominal foot poses from forward kinematics
nominal_foot_poses = []

As = np.arange(4).tolist()
freqs = np.arange(1).tolist()

for f in freqs:
    omega = 2 * np.pi * f
    for A in As:
        print("current Frequancy:", f,"and Amplitude:", A)
        start_time = time.time()
        # For each combination of A, f collect data for 10 seconds
        while (time.time() - start_time < 10):
            
            # Get current state and Transformation matrix
            state = robot.getJointStates()
            T = getT()
            
            # Update Poses
            # model.updateAllPose(state['q'], state['dq'], T, np.zeros(6))
            
            # Generate foot traj
            t = time.time() - start_time
            feet_pos = generate_traj(A, f, t, nominal_foot_poses) 
            # Apply inverse kinematics to get q_target
            q_target = model.inverseKinematics(getT(),feet_pos) 
            # Apply q_target
            dq = np.zeros(12)
            kp = np.ones(12)*3.0
            kd = np.ones(12)*0.1
            kp[:3] = 0
            kp[6:] = 0
            kd[:3] = 0
            kd[6:] = 0
            print(kp, kd)
            pd_law = 1*6.3*(q_target-state['q']) + 1*0.5*(dq-state['dq'])
            tau_ff = pd_law

            # robot.setCommands(q_target, dq, kp, kd, np.zeros(12))
            robot.step()
            if np.isnan(state['tau_est'].reshape(-1)).any():
                print("Warning: NaN values detected in tau_est")
            # Save data
            data.append([state['tau_est'].reshape(-1), np.zeros(12), state['q'], q_target, state['dq']])
            time.sleep(0.01)

# %%
# Verify dimensions
print("tau:", tau_ff.shape)
print("tau_est", state['tau_est'].shape)
print("q:", state['q'].shape)
print("q_target", q_target.shape)
print("dq:", dq.shape)


data = np.array(data)
# Save to pickle file
import pickle
with open('actuator_net_dataset_sim2.pkl', 'wb') as f:
    pickle.dump(
        {'tau_est': data[:,0],
         'torques': data[:,1],
         'joint_pos': data[:,2],
         'joint_pos_target': data[:,3],
         'joint_vel': data[:,4]},
         f
    )

# %% [markdown]
# # Real Robot

# %%
from Go2Py.robot.interface import GO2Real
from Go2Py.robot.model import Go2Model
from scipy.spatial.transform import Rotation as R
import numpy as np
import time


model = Go2Model()
robot = GO2Real()
data =[]
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.8.19)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
state = robot.getJointStates()
print(state.keys())
print(state)

data = [] # should contain q, q_target, dq, tau_est, tau
# Out:
# dict_keys(['q', 'dq', 'tau_est', 'temperature'])
# {'q': [-0.04112428426742554, 1.2605890035629272, -2.787384033203125, 0.045272305607795715, 1.2619211673736572, -2.8102264404296875, -0.3544110059738159, 1.2830191850662231, -2.8211264610290527, 0.34193670749664307, 1.2835944890975952, -2.7998480796813965], 'dq': [0.027128666639328003, -0.011626571416854858, -0.0020220123697072268, -0.01937761902809143, 0.03100419044494629, -0.03033018670976162, -0.054257333278656006, -0.10463915020227432, 0.036396224051713943, -0.03875523805618286, 0.015502095222473145, 0.006066037341952324], 'tau_est': [-0.049476563930511475, 0.049476563930511475, -0.04741504043340683, -0.07421484589576721, -0.07421484589576721, 0.04741504043340683, 0.049476563930511475, 0.049476563930511475, 0.0, 0.024738281965255737, 0.0, 0.0], 'temperature': [26.0, 26.0, 26.0, 25.0, 25.0, 26.0, 26.0, 26.0, 26.0, 26.0, 25.0, 26.0]}

# %%
for i in range(1000000):
    q = np.zeros(12) 
    dq = np.zeros(12)
    kp = np.ones(12)*0.0
    kd = np.ones(12)*0.0
    tau = np.zeros(12)
    tau[0] = 0.0
    robot.setCommands(q, dq, kp, kd, tau)
    time.sleep(0.01)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       7 tau[0] = 0.0
#       8 robot.setCommands(q, dq, kp, kd, tau)
# ----> 9 time.sleep(0.01)
#
# KeyboardInterrupt:

# %%
import numpy as np

def generate_traj(A, f, t, current_foot_poses):
    """
    Generate the foot trajectories using a sine wave and modify the current foot positions.

    Args:
        A (float): Amplitude of the sine wave in centimeters.
        f (float): Frequency of the sine wave in Hz.
        t (float): Current time in seconds.
        current_foot_poses (dict): A dictionary where keys are frame names (e.g., 'FR_foot') 
                                   and values are 4x4 transformation matrices.

    Returns:
        np.ndarray: A numpy array of size 12 containing the modified foot positions 
                    in the world frame (flattened as [FR_x, FR_y, FR_z, FL_x, FL_y, FL_z, ...]).
    """
    A = A / 100  # Convert amplitude to meters
    omega = 2 * np.pi * f
    x_traj = A * np.cos(omega * t)  # X trajectory (circular motion)
    z_traj = A * np.sin(omega * t)  # Z trajectory (circular motion)
    y_traj = A * np.sin(2 * omega * t)  # Y trajectory (lateral motion)

    x_traj_off = A * np.cos(omega * t + np.pi)  # X trajectory (circular motion)
    z_traj_off = A * np.sin(omega * t + np.pi)  # Z trajectory (circular motion)
    y_traj_off = A * np.sin(2 * omega * t + np.pi) 

    # Offsets for each foot
    feet_offsets = {
        # 'FR_foot': np.array([x_traj_off, y_traj_off, z_traj_off]),
        'FR_foot': np.array([0, 0, 0]),
        'FL_foot': np.array([0, 0, z_traj]),
        'RR_foot': np.array([0, 0, 0]),  
        'RL_foot': np.array([0, 0, 0]),
        # 'RR_foot': np.array([x_traj, y_traj, z_traj]),  
        # 'RL_foot': np.array([x_traj_off, y_traj_off, z_traj_off]),
    }

    # Store the updated foot positions in a numpy array
    feet_pos = np.zeros(12)  # 4 feet × 3 coordinates (x, y, z)

    foot_order = ['FR_foot', 'FL_foot', 'RR_foot', 'RL_foot']  # Ensure correct order
    for i, foot in enumerate(foot_order):
        if foot in current_foot_poses:
            # Extract translation (position) from the homogeneous transformation matrix
            translation = current_foot_poses[foot][:3, 3]  
            # Apply the offset
            modified_translation = translation #+ feet_offsets[foot]
            # Store in the numpy array
            feet_pos[3 * i: 3 * i + 3] = modified_translation  

    return feet_pos  # Returns a 12-element numpy array

# %%
def getT():
    position, quaternion = robot.getPose()
    rotation_matrix = R.from_quat([quaternion[1], quaternion[2], quaternion[3], quaternion[0]]).as_matrix()
    T = np.eye(4)
    T[:3, :3] = rotation_matrix
    T[:3, 3] = position
    
    return T

# %%
# get nominal foot positions
while True:

    q = np.zeros(12) 
    dq = np.zeros(12)
    kp = np.ones(12)*0.0
    kd = np.ones(12)*0.0
    tau = np.zeros(12)
    tau[0] = 0.0
    robot.setCommands(q, dq, kp, kd, tau)

    state = robot.getJointStates()
    q = np.array(state['q'])
    foot_pos = model.forwardKinematics(np.eye(4), q) # Get nominal foot poses from forward kinematics
    print(foot_pos['FL_foot'][:3,3])

    
    time.sleep(1)

#  [ 0.34835959  0.22471502 -0.07046597]
#  [ 0.20625531  0.2808269  -0.16363015]
#  [ 0.04853118  0.21627886 -0.1713757 ]

# %%
# Data Collector 
T = np.eye(4)
state = robot.getJointStates()
# model.updateAllPose(state['q'], state['dq'], T, np.zeros(6))

start_time = time.time()
q_nominal = np.array(state['q'])
nominal_foot_poses = model.forwardKinematics(T, q_nominal) # Get nominal foot poses from forward kinematics
FL_foot_poses = [[0.34835959,  0.22471502, -0.15046597], [ 0.20625531,  0.2808269 , -0.16363015], [ 0.04853118,  0.21627886 ,-0.1713757 ]]
# FL_foot_poses  = [[ 0.20625531,  0.2808269 , -0.19363015]]
# #As = list(range(2, 7))
# As = np.arange(4).tolist()
# freqs = np.arange(1).tolist()


# for i in range(len(FL_foot_poses)):
#     for f in freqs:
#         omega = 2 * np.pi * f
#         for A in As:
#             print("current Frequancy:", f,"and Amplitude:", A)
#             start_time = time.time()
#             # For each combination of A, f collect data for 10 seconds
#             while (time.time() - start_time < 10):
                
#                 # Get current state and Transformation matrix
#                 state = robot.getJointStates()
#                 T = np.eye(4)
                
#                 # Update Poses
#                 # model.updateAllPose(state['q'], state['dq'], T, np.zeros(6))
                
#                 # Generate foot traj
#                 t = time.time() - start_time
#                 nominal_foot_poses['FL_foot'][:3,3] = FL_foot_poses[i]
#                 feet_pos = generate_traj(A, f, t, nominal_foot_poses) 
#                 # Apply inverse kinematics to get q_target
#                 q_target = model.inverseKinematics(T,feet_pos) 
#                 # Apply q_target
#                 dq = np.zeros(12)
#                 kp = np.ones(12)*3.0
#                 kd = np.ones(12)*0.1
#                 kp[:3] = 0
#                 kp[6:] = 0
#                 kd[:3] = 0
#                 kd[6:] = 0
#                 pd_law = 1*6.3*(q_target-state['q']) + 1*0.5*(dq-state['dq'])
#                 tau_ff = pd_law

#                 robot.setCommands(q_target, dq, kp, kd, tau_ff)

#                 tau_est = np.array(state['tau_est'])  # Convert list to NumPy array
#                 if np.isnan(tau_est.reshape(-1)).any():
#                     print("Warning: NaN values detected in tau_est")
#                 # Save data
#                 data.append([tau_est, tau_ff, state['q'], q_target, state['dq']])
#                 time.sleep(0.01)
As = np.arange(0.4, 0.45, 0.025).tolist()
freqs = np.arange(1, 3, 1).tolist()

for i in range(len(FL_foot_poses)):
    for f in freqs:
        omega = 2 * np.pi * f
        for A in As:
            print("current Frequancy:", f,"and Amplitude:", A)
            start_time = time.time()
            # For each combination of A, f collect data for 10 seconds
            while (time.time() - start_time < 10):
                
                # Get current state and Transformation matrix
                state = robot.getJointStates()
                T = np.eye(4)
        
                # Generate foot traj
                t = time.time() - start_time
                nominal_foot_poses['FL_foot'][:3,3] = FL_foot_poses[i]
                feet_pos = generate_traj(A, f, t, nominal_foot_poses) 
                # Apply inverse kinematics to get q_target
                q_target = model.inverseKinematics(T,feet_pos) 
                q_target[5] = q_target[5] + A * np.sin(omega*t)
                # Apply q_target
                dq = np.zeros(12)
                kp = np.ones(12)*3.0
                kd = np.ones(12)*0.1
                tau_ff = np.zeros(12)
                kp[:3] = 0 
                kp[6:] = 0 
                kd[:3] = 0 
                kd[6:] = 0 
                # Calculate the idealized torques for plotting purposes
                torques = kp*(q_target - state['q']) + kd*(dq - state['dq'])

                robot.setCommands(q_target, dq, kp, kd, tau_ff)
                tau_est = np.array(state['tau_est'])
                if np.isnan(tau_est.reshape(-1)).any():
                    print("Warning: NaN values detected in tau_est")
                # Save data
                data.append([tau_est.reshape(-1), torques, state['q'], q_target, state['dq']])
                time.sleep(0.01)
# Out:
# current Frequancy: 1 and Amplitude: 0.4
# current Frequancy: 1 and Amplitude: 0.42500000000000004
# current Frequancy: 2 and Amplitude: 0.4
# current Frequancy: 2 and Amplitude: 0.42500000000000004
# current Frequancy: 1 and Amplitude: 0.4
# current Frequancy: 1 and Amplitude: 0.42500000000000004
# current Frequancy: 2 and Amplitude: 0.4
# current Frequancy: 2 and Amplitude: 0.42500000000000004
# current Frequancy: 1 and Amplitude: 0.4
# current Frequancy: 1 and Amplitude: 0.42500000000000004
# current Frequancy: 2 and Amplitude: 0.4
# current Frequancy: 2 and Amplitude: 0.42500000000000004

# %%
# Verify dimensions
tau_est = np.array(state['tau_est'])
q = np.array(state['q'])
print("tau:", tau_ff.shape)
print("tau_est", tau_est.shape)
print("q:", q.shape)
print("q_target", q_target.shape)
print("dq:", dq.shape)


data = np.array(data)
# Save to pickle file
import pickle
with open('actuator_net_dataset_real3.pkl', 'wb') as f:
    pickle.dump(
        {'tau_est': data[:,0],
         'torques': data[:,1],
         'joint_pos': data[:,2],
         'joint_pos_target': data[:,3],
         'joint_vel': data[:,4]},
         f
    )
# Out:
# tau: (12,)
# tau_est (12,)
# q: (12,)
# q_target (12,)
# dq: (12,)
# 1747852173.638201 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852173.638252 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852174.438372 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852174.438411 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852176.038494 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852176.038529 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:47883 failed with retcode -1
# 1747852177.638607 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852179.036764 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852179.136244 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852179.136282 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852179.136829 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852179.236972 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852179.337063 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852179.437214 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852179.537373 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852179.637511 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852179.837660 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852180.037768 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852180.437933 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852180.838075 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852181.638229 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852182.438362 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852184.038506 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852187.136544 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852187.136594 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852195.136692 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852195.136743 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852203.136844 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852203.136882 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852211.136991 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852211.137029 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852219.137141 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852219.137180 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852227.137448 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852227.137487 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852235.137590 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852235.137629 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852243.137732 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852243.137767 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852251.137906 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852251.137946 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852259.138062 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852259.138100 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852267.138211 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852267.138250 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852275.138372 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852275.138410 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852283.138512 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852283.138551 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852291.138668 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852291.138707 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852299.138824 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852299.138863 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852356.041426 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852356.041465 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852356.441524 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852356.441576 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852356.841599 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852356.841634 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852357.641794 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852357.641834 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852358.441934 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852358.441972 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852360.042075 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852361.642230 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852363.040280 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852363.140117 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852363.140156 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852363.140309 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852363.240480 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852363.340640 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852363.440725 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852363.540822 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852363.640925 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852363.841087 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852364.041208 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852364.441397 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852364.841494 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852365.641636 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852366.441729 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852371.140283 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852371.140342 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852379.140447 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852379.140485 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852387.140533 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852387.140570 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852395.140618 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852395.140652 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852403.140739 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852403.140773 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852411.140891 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852411.140942 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852419.141042 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852419.141094 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852427.141363 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852427.141416 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852435.141583 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852435.141633 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852443.141739 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852443.141790 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852451.141890 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852451.141940 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852459.142051 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852459.142108 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852467.142204 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852467.142261 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852475.142496 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852475.142546 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852483.142655 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852483.142706 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852491.142807 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852491.142857 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852499.142960 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852499.143011 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852507.143120 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852507.143177 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852515.143281 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852515.143372 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852523.143429 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852523.143479 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852531.143573 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852531.143623 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852539.143725 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852539.143777 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852547.143887 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852547.143936 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852555.144040 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852555.144091 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852563.144173 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852563.144209 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852571.144370 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852571.144412 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852579.144476 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852579.144522 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852587.144644 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852587.144694 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852595.144771 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852595.144821 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852603.144913 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852603.144962 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852611.145065 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852611.145116 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852619.145227 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852619.145278 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852627.145518 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852627.145569 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852635.145603 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852635.145655 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852643.145761 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852643.145812 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852651.145929 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852651.145981 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852659.146089 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852659.146138 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852667.146230 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852667.146280 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852675.146406 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852675.146457 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852683.146483 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852683.146539 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852691.146631 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852691.146680 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852699.146733 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852699.146770 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852707.146881 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852707.146920 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852715.147145 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852715.147183 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852723.147297 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852723.147359 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852731.147606 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852731.147646 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852739.147753 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852739.147790 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852747.147873 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852747.147924 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852755.147991 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852755.148029 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852763.148072 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852763.148105 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852771.148229 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852771.148267 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852779.148400 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852779.148452 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852787.148515 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852787.148565 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852795.148633 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852795.148688 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852803.148772 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852803.148807 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852811.148917 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852811.148956 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852819.149068 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852819.149107 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852827.149390 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852827.149437 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852835.149469 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852835.149509 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852843.149544 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852843.149580 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852851.149707 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852851.149746 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852859.149843 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852859.149880 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852867.150000 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852867.150039 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852875.150279 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852875.150349 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852883.150424 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852883.150464 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852891.150559 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852891.150598 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852899.150699 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852899.150739 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852907.150852 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852907.150891 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852915.150993 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852915.151032 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852923.151134 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852923.151173 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852931.151269 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852931.151309 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852939.151447 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852939.151485 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852947.151490 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852947.151527 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852955.151577 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852955.151616 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852963.151643 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852963.151691 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852971.151894 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852971.151943 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852979.152041 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852979.152092 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852987.152195 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852987.152247 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747852995.152380 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747852995.152432 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853003.152489 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853003.152539 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853011.152628 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853011.152685 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853019.152776 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853019.152831 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853027.153008 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853027.153047 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853035.153161 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853035.153200 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853043.153314 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853043.153376 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853051.153453 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853051.153493 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853059.153591 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853059.153630 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853067.153730 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853067.153770 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853075.153974 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853075.154013 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853083.154120 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853083.154159 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853091.154280 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853091.154341 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853099.154440 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853099.154479 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853107.154659 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853107.154701 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853115.154794 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853115.154832 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853123.154956 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853123.154995 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853131.155114 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853131.155153 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853139.155426 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853139.155465 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853147.155523 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853147.155563 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853155.155671 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853155.155709 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853163.155900 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853163.155940 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853171.156156 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853171.156195 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853179.156304 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853179.156367 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853187.156462 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853187.156501 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853195.156628 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853195.156667 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853203.156857 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853203.156895 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853211.157108 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853211.157159 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853219.157418 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853219.157459 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853227.157632 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853227.157688 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853235.157754 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853235.157804 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853243.157995 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853243.158045 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853251.158250 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853251.158300 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853259.158436 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853259.158487 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853267.158572 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853267.158623 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853275.158733 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853275.158784 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853283.158898 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853283.158949 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853291.159049 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853291.159100 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853299.159206 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853299.159253 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853307.159404 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853307.159455 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853315.159504 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853315.159555 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853323.159647 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853323.159699 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853331.159780 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853331.159819 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853339.159913 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853339.159951 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853347.160067 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853347.160106 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853355.160224 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853355.160262 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853363.160523 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853363.160561 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853371.160656 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853371.160695 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853379.160814 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853379.160853 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853387.160977 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853387.161028 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853395.161116 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853395.161166 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853403.161440 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853403.161479 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853411.161531 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853411.161570 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853419.161698 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853419.161737 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853427.161847 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853427.161886 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853435.162109 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853435.162159 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853443.162259 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853443.162298 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853451.162436 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853451.162475 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853459.162589 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853459.162628 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853467.162746 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853467.162785 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853475.162906 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853475.162945 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853483.163026 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853483.163075 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853491.163108 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853491.163156 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853499.163270 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853499.163345 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853507.163438 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853507.163489 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853515.163604 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853515.163654 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853523.163725 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853523.163774 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853531.163885 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853531.163935 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853539.164150 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853539.164200 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853547.164279 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853547.164369 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853555.164448 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853555.164497 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853563.164618 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853563.164668 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853571.164750 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853571.164800 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853579.164879 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853579.164929 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853587.165139 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853587.165189 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853595.165289 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853595.165366 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853603.165606 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853603.165663 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853611.165758 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853611.165808 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853619.165892 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853619.165943 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853627.166030 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853627.166080 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853635.166159 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853635.166210 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853643.166346 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853643.166399 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853651.166485 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853651.166534 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853659.166720 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853659.166770 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853667.166876 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853667.166926 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853675.167136 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853675.167185 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853683.167290 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853683.167386 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853691.167450 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853691.167500 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853699.167619 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853699.167669 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853707.167745 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853707.167795 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853715.167882 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853715.167932 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853723.168037 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853723.168087 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853731.168202 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853731.168252 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853739.168375 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853739.168415 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853747.168502 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853747.168541 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853755.168584 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853755.168635 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853763.952099 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853763.952151 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853771.952222 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853771.952283 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853779.952360 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853779.952397 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853787.952500 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853787.952539 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853795.952652 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853795.952723 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853803.952828 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853803.952869 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853811.952970 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853811.953008 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853819.953129 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853819.953168 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853827.953244 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853827.953279 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853835.953440 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853835.953481 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853843.953551 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853843.953604 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853851.953704 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853851.953743 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853859.953843 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853859.953885 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853867.953957 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853867.953996 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853875.954100 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853875.954139 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853883.954237 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853883.954277 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853891.954480 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853891.954519 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853899.954628 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853899.954690 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853907.954786 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747853907.954825 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747853915.954926 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# ...
# 1747860972.092799 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747860972.092838 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747860980.092967 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747860980.093006 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747860988.093117 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747860988.093157 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747860996.093257 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747860996.093297 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861004.093390 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861004.093429 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861012.093523 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861012.093562 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861020.093665 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861020.093752 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861028.093831 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861028.093871 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861036.093966 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861036.094006 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861044.094104 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861044.094142 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861052.094255 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861052.094294 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861060.094389 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861060.094428 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861068.094503 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861068.094557 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861076.094625 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861076.094688 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861084.094784 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861084.094823 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861092.094908 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861092.094948 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861100.095192 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861100.095232 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861108.095340 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861108.095379 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861116.095481 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861116.095518 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861124.095647 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861124.095707 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861132.095780 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861132.095819 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861140.095911 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861140.095947 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861148.096054 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861148.096093 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861156.096210 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861156.096248 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861164.096373 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861164.096413 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861172.096445 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861172.096486 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861180.096580 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861180.096618 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861188.096877 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861188.096916 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861196.097089 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861196.097127 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861204.097324 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861204.097362 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861212.097447 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861212.097486 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861220.097605 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861220.097644 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861228.097766 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861228.097805 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861236.097831 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861236.097870 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861244.097976 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861244.098015 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861252.098126 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861252.098165 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861260.098287 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861260.098326 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861268.098558 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861268.098596 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861276.098735 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861276.098773 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861284.098861 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861284.098899 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861292.099007 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861292.099047 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861300.099237 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861300.099276 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861308.099325 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861308.099370 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861316.099447 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861316.099486 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861324.099582 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861324.099620 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861332.099741 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861332.099780 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861340.099845 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861340.099884 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861348.100072 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861348.100110 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861356.100198 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861356.100236 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861364.100454 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861364.100493 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861372.100602 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861372.100640 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861380.100777 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861380.100835 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861388.100863 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861388.100902 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861396.101001 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861396.101039 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861404.101222 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861404.101261 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861412.101373 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861412.101411 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861420.101468 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861420.101507 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861428.101622 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861428.101661 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861436.101929 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861436.101968 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861444.102018 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861444.102058 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861452.102162 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861452.102200 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861460.102314 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861460.102353 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861468.102471 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861468.102510 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861476.102630 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861476.102706 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861484.102790 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861484.102828 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861492.102951 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861492.102990 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861500.103105 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861500.103143 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861508.103265 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861508.103303 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861516.103423 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861516.103461 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861524.103552 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861524.103589 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861532.103715 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861532.103753 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861540.103794 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861540.103840 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861548.103913 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861548.103952 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861556.103992 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861556.104028 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861564.104160 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861564.104198 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861572.104302 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861572.104338 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861580.104577 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861580.104616 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
# 1747861588.104615 [0]        tev: ddsi_udp_conn_write to udp/239.255.0.1:7400 failed with retcode -1
# 1747861588.104632 [0]        tev: ddsi_udp_conn_write to udp/192.168.123.18:7410 failed with retcode -1
